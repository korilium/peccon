# %%
using Pkg

# %%
Pkg.add(["DataFrames", "MarketData", "CSV", "Plots", "StatsPlots", "LoopVectorization",
    "Distributions", "StatsBase", "OnlineStats"])
# Out:
#    Resolving package versions...
#    Installed GR_jll ─────────────────────────── v0.64.3+0
#    Installed Calculus ───────────────────────── v0.5.1
#    Installed Libmount_jll ───────────────────── v2.35.0+0
#    Installed JpegTurbo_jll ──────────────────── v2.1.2+0
#    Installed x265_jll ───────────────────────── v3.5.0+0
#    Installed libfdk_aac_jll ─────────────────── v2.0.2+0
#    Installed SIMDDualNumbers ────────────────── v0.1.1
#    Installed OffsetArrays ───────────────────── v1.12.0
#    Installed HypergeometricFunctions ────────── v0.3.10
#    Installed StatsFuns ──────────────────────── v1.0.1
#    Installed LERC_jll ───────────────────────── v3.0.0+1
#    Installed Opus_jll ───────────────────────── v1.3.2+0
#    Installed Xorg_xkbcomp_jll ───────────────── v1.4.2+4
#    Installed FFTW ───────────────────────────── v1.4.6
#    Installed RelocatableFolders ─────────────── v0.1.3
#    Installed PDMats ─────────────────────────── v0.11.10
# ...

# %%
ticker = ["IBCI.AS", "IUSA.AS" , "IEMA.AS"]
amount_stock = [1,5,1]
dollar_value =  [241.64,41.331,34.98]
total_amount = sum(dollar_value .* amount_stock )

weights = (dollar_value .* amount_stock)./ total_amount
start_date = DateTime(2018,1,1)
# Out:
# UndefVarError: DateTime not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[10]:7
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196
